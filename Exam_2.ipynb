# %% [markdown]
# <a href="https://colab.research.google.com/github/BxMild/Python_dataviz2024/blob/main/Exam_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
df_crime = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/crime_scene_report.csv')
df_person = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/person.csv')
df_interview = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/interview.csv')
df_income = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/income.csv')
df_getfitnow_member = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/get_fit_now_member.csv')
df_getfitnow_checkin = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/get_fit_now_check_in.csv')
df_facebook_checkin = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/facebook_event_checkin.csv')
df_drivers_license = pd.read_csv('/content/drive/My Drive/Data_viz_2024/Exam_2/drivers_license.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_crime.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
# prompt: หาคดี murder ที่เกิดขึ้น 20180115 ที่เมือง SQL City

df_crime[(df_crime['type'] == 'murder') & (df_crime['date'] == 20180115) & (df_crime['city'] == 'SQL City')]
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %%
df_person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
#แยกชื่อขนาม-สกุล
df_person[['first_name', 'last_name']] = df_person['name'].str.split(' ',n=1, expand=True)
df_person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn  first_name   last_name
# 0  747714076  Christoper     Peteuil
# 1  477972044    Kourtney  Calderwood
# 2  828638512        Muoi        Cary
# 3  614621061         Era     Moselle
# 4  223877684       Trena      Hornby

# %%
#คนแรกอยู่บ้านหลังสุดท้ายใน Northwestern Dr
last_house_on_street = df_person[df_person['address_street_name'] == 'Northwestern Dr']
last_house_on_street = last_house_on_street.loc[last_house_on_street['address_number'].idxmax()]
last_house_on_street
# Out:
# id                               14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# first_name                       Morty
# last_name                     Schapiro
# Name: 499, dtype: object

# %%
#คนสองชื่อ Annabel
second_witness = df_person[df_person['first_name'] == 'Annabel']
second_witness
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn first_name last_name
# 665  318771143    Annabel    Miller

# %%
df_interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
#เอาเลขทั้งสองคนมาหาคำให้การ
df_interview = df_interview[(df_interview['person_id'] == 16371) | (df_interview['person_id'] == 14887)]
df_interview
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
df_getfitnow_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
# prompt: membership_status is gold and id start 48Z
df_getfitnow_member[(df_getfitnow_member['membership_status'] == 'gold') & (df_getfitnow_member['id'].str.startswith('48Z'))]
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
df_getfitnow_checkin.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
# prompt: check_in_date is 20180109 and membership_id is 48Z55 and 48Z7A
df_getfitnow_checkin[(df_getfitnow_checkin['check_in_date'] == 20180109) &
                     ((df_getfitnow_checkin['membership_id'] == '48Z55') |
                      (df_getfitnow_checkin['membership_id'] == '48Z7A'))]
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700

# %%
df_drivers_license.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
# prompt: รถที่มีป้ายทะเบียนที่ประกอบด้วยตัวอักษร H,4,2, W และผู้ชายขับ

# หาป้ายทะเบียนที่มี H,4,2, W
license_plates = df_drivers_license[df_drivers_license['plate_number'].str.contains('H') &
                                     df_drivers_license['plate_number'].str.contains('4') &
                                     df_drivers_license['plate_number'].str.contains('2') &
                                     df_drivers_license['plate_number'].str.contains('W')]
#เลือกเฉพาะผู้ชาย
license_plates = license_plates[license_plates['gender'].isin(['male'])]
license_plates
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 6240  664760   21      71     black      black   male       4H42WR     Nissan
#
#      car_model
# 3529  Spark LS
# 6240    Altima

# %%
df_person[df_person['license_id'].isin(license_plates['id'])]
# Out:
#          id            name  license_id  address_number  \
# 4664  51739  Tushar Chandra      664760             312
# 6327  67318   Jeremy Bowers      423327             530
#
#         address_street_name        ssn first_name last_name
# 4664                 Phi St  137882671     Tushar   Chandra
# 6327  Washington Pl, Apt 3A  871539279     Jeremy    Bowers
